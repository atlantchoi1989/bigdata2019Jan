# %% [markdown]
# <a href="https://colab.research.google.com/github/atlantchoi1989/bigdata2019Jan/blob/master/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EB%B3%B8_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
plt.figure()
plt.plot([1,2,3,4,5,6,7,8,9,8,7,6,5,4,3,2,1])
plt.show()

# %%
t = np.arange(0, 12, 0.01)

# %%
y = np.sin(t)
z = np.cos(t)

# %%
plt.figure(figsize=(10,6))
plt.plot(t, y, label='sin', lw=5)
plt.plot(t, z, 'r--', label='cos')
plt.legend()

plt.grid()

plt.xlabel('time')
plt.ylabel('value') 
plt.title('my graph!!')







plt.show()

# %%
t2 = np.arange(0, 5, 0.5)

# %%
plt.figure(figsize=(10,6))

# %%
plt.plot(t2, t2, 'r--')
plt.plot(t2, t2*2, 'bs')
plt.plot(t2, t2*3, 'g^')
plt.plot(t2, t2*4, color='pink', linestyle='dashed', marker='o')
plt.show()

# %%
s1 = np.random.normal(loc=0, scale=1,size=1000)
s2 = np.random.normal(loc=5, scale=0.5,size=1000)
s3 = np.random.normal(loc=10, scale=2,size=1000)

# %%
plt.figure(figsize=(10,6))
plt.plot(s1, label='s1')
plt.plot(s2, label='s2')
plt.plot(s3, label='s3')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.boxplot((s1, s2, s3))



plt.show()
